# %% [markdown]
# # Text Translation and Sentiment Analysis using Transformers

# %% [markdown]
# ## Project Overview:
#
# The objective of this project is to analyze the sentiment of movie reviews in three different languages - English, French, and Spanish. We have been given 30 movies, 10 in each language, along with their reviews and synopses in separate CSV files named `movie_reviews_eng.csv`, `movie_reviews_fr.csv`, and `movie_reviews_sp.csv`.
#
# - The first step of this project is to convert the French and Spanish reviews and synopses into English. This will allow us to analyze the sentiment of all reviews in the same language. We will be using pre-trained transformers from HuggingFace to achieve this task.
#
# - Once the translations are complete, we will create a single dataframe that contains all the movies along with their reviews, synopses, and year of release in all three languages. This dataframe will be used to perform sentiment analysis on the reviews of each movie.
#
# - Finally, we will use pretrained transformers from HuggingFace to analyze the sentiment of each review. The sentiment analysis results will be added to the dataframe. The final dataframe will have 30 rows
#
#
# The output of the project will be a CSV file with a header row that includes column names such as **Title**, **Year**, **Synopsis**, **Review**, **Review Sentiment**, and **Original Language**. The **Original Language** column will indicate the language of the review and synopsis (*en/fr/sp*) before translation. The dataframe will consist of 30 rows, with each row corresponding to a movie.

# %%
# imports
import pandas as pd
from transformers import MarianMTModel, MarianTokenizer
from transformers import pipeline

# %% [markdown]
# ### Get data from `.csv` files and then preprocess data

# %%
# use the `pd.read_csv()` function to read the movie_review_*.csv files into 3 separate pandas dataframes

# Note: All the dataframes would have different column names. For testing purposes
# you should have the following column names/headers -> [Title, Year, Synopsis, Review]

def preprocess_data() -> pd.DataFrame:
    """
    Reads movie data from .csv files, map column names, add the "Original Language" column,
    and finally concatenate in one resultant dataframe called "df".
    """
    df_eng = pd.read_csv("data/movie_reviews_eng.csv")
    #TODO 1: Add your code here
    df_eng = df_eng.rename(columns={"Movie / TV Series": "Title"})
    df_eng.insert(4, "Original Language", ["en" for _ in range(len(df_eng))], True)
    
    df_sp = pd.read_csv("data/movie_reviews_sp.csv")
    df_sp = df_sp.rename(columns={"Título": "Title", "Año": "Year", "Sinopsis": "Synopsis", "Críticas": "Review"})
    df_sp.insert(4, "Original Language", ["sp" for _ in range(len(df_sp))], True)

    
    df_fr = pd.read_csv("data/movie_reviews_fr.csv")
    df_fr = df_fr.rename(columns={"Titre": "Title", "Année": "Year", "Synopsis": "Synopsis", "Critiques": "Review"})
    df_fr.insert(4, "Original Language", ["fr" for _ in range(len(df_fr))], True)

    df = pd.concat([df_eng, df_sp, df_fr], ignore_index=True)
    
    return df

df = preprocess_data()

# %%
df.sample(10)
# Out:
#                                   Title  Year  \
# 3                        The Godfather   1972
# 14                        Amores perros  2000
# 23                        Les Choristes  2004
# 16                              Toc Toc  2017
# 6           Scott Pilgrim vs. the World  2010
# 17                               El Bar  2017
# 5                     Blade Runner 2049  2017
# 24  Le Fabuleux Destin d'Amélie Poulain  2001
# 26       La Tour Montparnasse Infernale  2001
# 27          Astérix aux Jeux Olympiques  2008
#
#                                              Synopsis  \
# 3   Don Vito Corleone (Marlon Brando) is the head ...
# 14  Tres historias se entrelazan en esta película ...
# 23  Ce film raconte l'histoire d'un professeur de ...
# 16  En esta comedia española, un grupo de personas...
# 6   Scott Pilgrim (Michael Cera) must defeat his n...
# 17  Un grupo de personas quedan atrapadas en un ba...
# 5   Officer K (Ryan Gosling), a new blade runner f...
# 24  Cette comédie romantique raconte l'histoire d'...
# 26  Deux employés de bureau incompétents se retrou...
# 27  Dans cette adaptation cinématographique de la ...
#
#                                                Review Original Language
# 3   "The Godfather is a classic movie that stands ...                en
# 14  "Amores perros es una película intensa y conmo...                sp
# 23  "Les Choristes est un film magnifique qui vous...                fr
# 16  "Toc Toc es una película aburrida y poco origi...                sp
# 6   "It was difficult to sit through the whole thi...                en
# 17  "El Bar es una película ridícula y sin sentido...                sp
# 5   "Boring and too long. Nothing like the origina...                en
# 24  "Le Fabuleux Destin d'Amélie Poulain est un fi...                fr
# 26  "Je ne peux pas croire que j'ai perdu du temps...                fr
# 27  "Ce film est une déception totale. Les blagues...                fr

# %% [markdown]
# ### Text translation
#
# Translate the **Review** and **Synopsis** column values to English.

# %%
# load translation models and tokenizers
# TODO 2: Update the code below
fr_en_model_name = "Helsinki-NLP/opus-mt-fr-en"
es_en_model_name = "Helsinki-NLP/opus-mt-es-en"
fr_en_model = MarianMTModel.from_pretrained(fr_en_model_name)
es_en_model = MarianMTModel.from_pretrained(es_en_model_name)
fr_en_tokenizer = MarianTokenizer.from_pretrained(fr_en_model_name)
es_en_tokenizer = MarianTokenizer.from_pretrained(es_en_model_name)

# TODO 3: Complete the function below
def translate(text: str, model, tokenizer) -> str:
    """
    function to translate a text using a model and tokenizer
    """
    # encode the text using the tokenizer
    inputs = tokenizer(text, return_tensors="pt")

    # generate the translation using the model
    outputs = model.generate(**inputs)

    # decode the generated output and return the translated text
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return decoded

# %%
# TODO 4: Update the code below

# filter reviews in French and translate to English
fr_reviews = df.loc[df["Original Language"] == "fr"]["Review"]
fr_reviews_en = [translate(review, fr_en_model, fr_en_tokenizer) for review in fr_reviews]
# print(fr_reviews_en)

# filter synopsis in French and translate to English
fr_synopsis = df.loc[df["Original Language"] == "fr"]["Synopsis"]
fr_synopsis_en = [translate(syn, fr_en_model, fr_en_tokenizer) for syn in fr_synopsis]

# filter reviews in Spanish and translate to English
es_reviews = df.loc[df["Original Language"] == "sp"]["Review"]
es_reviews_en = [translate(review, es_en_model, es_en_tokenizer) for review in es_reviews]

# filter synopsis in Spanish and translate to English
es_synopsis = df.loc[df["Original Language"] == "sp"]["Synopsis"]
es_synopsis_en = [translate(syn, es_en_model, es_en_tokenizer) for syn in es_synopsis]

# update dataframe with translated text
# add the translated reviews and synopsis - you can overwrite the existing data
df.loc[df["Original Language"] == "fr", "Review"] = fr_reviews_en
df.loc[df["Original Language"] == "fr", "Synopsis"] = fr_synopsis_en
df.loc[df["Original Language"] == "sp", "Review"] = es_reviews_en
df.loc[df["Original Language"] == "sp", "Synopsis"] = es_synopsis_en
# Out:
# /home/mwalden/miniconda3/envs/udacity/lib/python3.7/site-packages/transformers/generation/utils.py:1357: UserWarning: Using `max_length`'s default (512) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,

# %%
df.sample(30)
# Out:
#                                   Title         Year  \
# 7                         The Nice Guys         2016
# 13               El Laberinto del Fauno         2006
# 3                        The Godfather          1972
# 4                             Inception         2010
# 17                               El Bar         2017
# 28            Les Visiteurs en Amérique         2000
# 16                              Toc Toc         2017
# 12                    Y tu mamá también         2001
# 8               Solo: A Star Wars Story         2018
# 11                     La Casa de Papel  (2017-2021)
# 14                        Amores perros         2000
# 6           Scott Pilgrim vs. the World         2010
# 22                               Amélie         2001
# 20                           La La Land         2016
# 0             The Shawshank Redemption          1994
# 24  Le Fabuleux Destin d'Amélie Poulain         2001
# 15                         Águila Roja   (2009-2016)
# 18   Torrente: El brazo tonto de la ley         1998
# 26       La Tour Montparnasse Infernale         2001
# 1                      The Dark Knight          2008
# 19                         El Incidente         2014
# 29                         Babylon A.D.         2008
# 25                     Le Dîner de Cons         1998
# 21                         Intouchables         2011
# 10                                 Roma         2018
# 2                          Forrest Gump         1994
# 23                        Les Choristes         2004
# 5                     Blade Runner 2049         2017
# 9                            The Island         2005
# 27          Astérix aux Jeux Olympiques         2008
#
#                                              Synopsis  \
# 7   In 1970s Los Angeles, a private eye (Ryan Gosl...
# 13  During the Spanish postwar period, Ofelia (Iva...
# 3   Don Vito Corleone (Marlon Brando) is the head ...
# 4   Dom Cobb (Leonardo DiCaprio) is a skilled thie...
# 17  A group of people are trapped in a bar after M...
# 28  In this continuation of the French comedy The ...
# 16  In this Spanish comedy, a group of people with...
# 12  Two teenage friends (Gael García Bernal and Di...
# 8   A young Han Solo (Alden Ehrenreich) joins a gr...
# 11  This Spanish television series follows a group...
# 14  Three stories intertwine in this Mexican film:...
# 6   Scott Pilgrim (Michael Cera) must defeat his n...
# 22  This romantic comedy tells the story of Amélie...
# 20  This musical tells the story of a budding actr...
# 0   Andy Dufresne (Tim Robbins), a successful bank...
# 24  This romantic comedy tells the story of Amélie...
# 15  This Spanish television series follows the adv...
# 18  In this Spanish comedy, a corrupt cop (played ...
# 26  Two incompetent office workers find themselves...
# 1   Batman (Christian Bale) teams up with District...
# 19  In this Mexican horror film, a group of people...
# 29  In the distant future, a mercenary has to esco...
# 25  The film follows the story of a group of rich ...
# 21  This film tells the story of the unlikely frie...
# 10  Cleo (Yalitza Aparicio) is a young domestic wo...
# 2   Forrest Gump (Tom Hanks) is a simple man with ...
# 23  This film tells the story of a music teacher w...
# 5   Officer K (Ryan Gosling), a new blade runner f...
# 9   In a future where people are cloned for organ ...
# 27  In this film adaptation of the popular comic s...
#
#                                                Review Original Language
# 7   "The Nice Guys tries too hard to be funny, and...                en
# 13  "The Labyrinth of Fauno is a fascinating and e...                sp
# 3   "The Godfather is a classic movie that stands ...                en
# 4   "Inception is a mind-bending and visually stun...                en
# 17  "The Bar is a ridiculous and meaningless film ...                sp
# 28  "The film is a total waste of time. The jokes ...                fr
# 16  "Toc Toc is a boring and unoriginal film that ...                sp
# 12  "And your mom is also a movie that stays with ...                sp
# 8   "Dull and pointless, with none of the magic of...                en
# 11  "The Paper House is an exciting and addictive ...                sp
# 14  "Amores dogs is an intense and moving film tha...                sp
# 6   "It was difficult to sit through the whole thi...                en
# 22  "Amélie is an absolutely charming film that wi...                fr
# 20  "The Land is an absolutely beautiful film with...                fr
# 0   "The Shawshank Redemption is an inspiring tale...                en
# 24  "The Fabulous Destiny of Amélie Poulain is an ...                fr
# 15  "Red Eagle is a boring and uninteresting serie...                sp
# 18  "Torrente is a vulgar and offensive film that ...                sp
# 26  "I can't believe I've wasted time watching thi...                fr
# 1   "The Dark Knight is a thrilling and intense su...                en
# 19  "The Incident is a boring and frightless film ...                sp
# 29  "This film is a complete mess. The characters ...                fr
# 25  "I didn't like this movie at all. The concept ...                fr
# 21  "Untouchables is an incredibly touching film w...                fr
# 10  "Rome is a beautiful and moving film that pays...                sp
# 2   "Forrest Gump is a heartwarming and inspiratio...                en
# 23  "The Choristes are a beautiful film that will ...                fr
# 5   "Boring and too long. Nothing like the origina...                en
# 9   "The Island is a bland and forgettable sci-fi ...                en
# 27  "This film is a complete disappointment. The j...                fr

# %% [markdown]
# ### Sentiment Analysis
#
# Use HuggingFace pretrained model for sentiment analysis of the reviews. Store the sentiment result **Positive** or **Negative** in a new column titled **Sentiment** in the dataframe.

# %%
# TODO 5: Update the code below
# load sentiment analysis model
from transformers import pipeline

model_name = "siebert/sentiment-roberta-large-english" 
sentiment_classifier = pipeline("sentiment-analysis",model="siebert/sentiment-roberta-large-english")
# print(sentiment_classifier("Kiss my butt!")[0]["label"])

# TODO 6: Complete the function below
def analyze_sentiment(text, classifier):
    """
    function to perform sentiment analysis on a text using a model
    """
    sentiment = classifier(text)[0]["label"]
    
    return sentiment
# Out:
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
df.insert(4, "Sentiment", ["" for _ in range(len(df))], True)

# %%
# TODO 7: Add code below for sentiment analysis
# perform sentiment analysis on reviews and store results in new column
for i in range(len(df)):
    df.loc[i, "Sentiment"] = analyze_sentiment(df.loc[i, "Review"], sentiment_classifier)

# %%
df.sample(10)
# Out:
#                           Title  Year  \
# 22                       Amélie  2001
# 21                 Intouchables  2011
# 6   Scott Pilgrim vs. the World  2010
# 1              The Dark Knight   2008
# 13       El Laberinto del Fauno  2006
# 19                 El Incidente  2014
# 14                Amores perros  2000
# 17                       El Bar  2017
# 4                     Inception  2010
# 3                The Godfather   1972
#
#                                              Synopsis  \
# 22  This romantic comedy tells the story of Amélie...
# 21  This film tells the story of the unlikely frie...
# 6   Scott Pilgrim (Michael Cera) must defeat his n...
# 1   Batman (Christian Bale) teams up with District...
# 13  During the Spanish postwar period, Ofelia (Iva...
# 19  In this Mexican horror film, a group of people...
# 14  Three stories intertwine in this Mexican film:...
# 17  A group of people are trapped in a bar after M...
# 4   Dom Cobb (Leonardo DiCaprio) is a skilled thie...
# 3   Don Vito Corleone (Marlon Brando) is the head ...
#
#                                                Review Sentiment  \
# 22  "Amélie is an absolutely charming film that wi...  POSITIVE
# 21  "Untouchables is an incredibly touching film w...  POSITIVE
# 6   "It was difficult to sit through the whole thi...  NEGATIVE
# 1   "The Dark Knight is a thrilling and intense su...  POSITIVE
# 13  "The Labyrinth of Fauno is a fascinating and e...  POSITIVE
# 19  "The Incident is a boring and frightless film ...  NEGATIVE
# 14  "Amores dogs is an intense and moving film tha...  POSITIVE
# 17  "The Bar is a ridiculous and meaningless film ...  NEGATIVE
# 4   "Inception is a mind-bending and visually stun...  POSITIVE
# 3   "The Godfather is a classic movie that stands ...  POSITIVE
#
#    Original Language
# 22                fr
# 21                fr
# 6                 en
# 1                 en
# 13                sp
# 19                sp
# 14                sp
# 17                sp
# 4                 en
# 3                 en

# %%
# export the results to a .csv file
df.to_csv("reviews_with_sentiment.csv", index=False)
